# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0527-boop/Nasscom-1/blob/main/Pandas_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

print("--- Intermediate Pandas Exercise ---")
print("Complete each task by writing the requested Pandas code.")
print("------------------------------------")

# Task 1: Basic Pandas Functions and Converting Arrays to DataFrames
print("\n--- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---")
# 1.1 Create a Pandas Series named 's1_1' from a list of numbers [10, 20, 30, 40, 50].
# 1.2 Create a 3x4 NumPy array named 'np_array1_2' with random integers between 1 and 100.
# 1.3 Convert 'np_array1_2' into a Pandas DataFrame named 'df1_3' with columns 'A', 'B', 'C', 'D'.

# Your code for Task 1 here:

print("--- Intermediate Pandas Exercise ---")
print("Complete each task by writing the requested Pandas code.")
print("------------------------------------")

# Task 1: Basic Pandas Functions and Converting Arrays to DataFrames
print("\n--- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---")

# 1.1 Create a Pandas Series named 's1_1' from a list of numbers [10, 20, 30, 40, 50].
s1_1 = pd.Series([10, 20, 30, 40, 50])

# 1.2 Create a 3x4 NumPy array named 'np_array1_2' with random integers between 1 and 100.
np_array1_2 = np.random.randint(1, 101, size=(3, 4))

# 1.3 Convert 'np_array1_2' into a Pandas DataFrame named 'df1_3' with columns 'A', 'B', 'C', 'D'.
df1_3 = pd.DataFrame(np_array1_2, columns=['A', 'B', 'C', 'D'])

# Display the results
print("\nSeries s1_1:")
print(s1_1)

print("\nNumPy Array np_array1_2:")
print(np_array1_2)

print("\nDataFrame df1_3:")
print(df1_3)


# Task 2: Synthetic Data Generation for Practice
print("\n--- Task 2: Synthetic Data Generation for Practice ---")
# Create a DataFrame named 'df_sales' with 100 rows and the following columns:
# - 'Date': A range of dates from '2023-01-01' to '2023-04-09' (inclusive).
# - 'Region': Randomly chosen from ['East', 'West', 'North', 'South'].
# - 'Product': Randomly chosen from ['Laptop', 'Mouse', 'Keyboard', 'Monitor'].
# - 'Sales': Random integers between 100 and 1000.
# - 'Quantity': Random integers between 1 and 10.
# - Introduce 5 random NaN values in the 'Sales' column and 3 random NaN values in the 'Quantity' column.

# Your code for Task 2 here:
# Task 2: Synthetic Data Generation for Practice
print("\n--- Task 2: Synthetic Data Generation for Practice ---")

# Create the DataFrame
df_sales = pd.DataFrame({
    'Date': pd.date_range(start='2023-01-01', periods=100),
    'Region': np.random.choice(['East', 'West', 'North', 'South'], 100),
    'Product': np.random.choice(['Laptop', 'Mouse', 'Keyboard', 'Monitor'], 100),
    'Sales': np.random.randint(100, 1001, 100).astype(float),      # float allows NaN values
    'Quantity': np.random.randint(1, 11, 100).astype(float)         # float allows NaN values
})

# Introduce NaN values
sales_nan_indices = np.random.choice(df_sales.index, size=5, replace=False)
df_sales.loc[sales_nan_indices, 'Sales'] = np.nan

quantity_nan_indices = np.random.choice(df_sales.index, size=3, replace=False)
df_sales.loc[quantity_nan_indices, 'Quantity'] = np.nan

# Display the first few rows
print(df_sales.head())

# Optional: Check the number of missing values
print("\nMissing values in each column:")
print(df_sales.isnull().sum())



# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")
# Use 'df_sales' from Task 2.
# 3.1 Select only the 'Region' and 'Sales' columns. Store it in 'df3_1'.
# 3.2 Select rows where 'Product' is 'Laptop'. Store it in 'df3_2'.
# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500. Store it in 'df3_3'.
# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor' (use .loc and .iloc). Store it in 'val3_4'.

# Your code for Task 3 here:
# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")

# 3.1 Select only the 'Region' and 'Sales' columns.
df3_1 = df_sales[['Region', 'Sales']]

# 3.2 Select rows where 'Product' is 'Laptop'.
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500.
df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]

# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor'
# (using .loc and .iloc).
val3_4 = df_sales.loc[df_sales['Product'] == 'Monitor', 'Sales'].iloc[0]

# Display the results
print("\ndf3_1:")
print(df3_1.head())

print("\ndf3_2:")
print(df3_2.head())

print("\ndf3_3:")
print(df3_3.head())

print("\nFirst 'Sales' value where Product is 'Monitor':")
print(val3_4)


# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")

# 3.1 Select only the 'Region' and 'Sales' columns.
df3_1 = df_sales[['Region', 'Sales']]

# 3.2 Select rows where 'Product' is 'Laptop'.
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500.
df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]

# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor'
# (using .loc and .iloc).
val3_4 = df_sales.loc[df_sales['Product'] == 'Monitor', 'Sales'].iloc[0]

# Display the results
print("\ndf3_1:")
print(df3_1.head())

print("\ndf3_2:")
print(df3_2.head())

print("\ndf3_3:")
print(df3_3.head())

print("\nFirst 'Sales' value where Product is 'Monitor':")
print(val3_4)# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")

# 3.1 Select only the 'Region' and 'Sales' columns.
df3_1 = df_sales[['Region', 'Sales']]

# 3.2 Select rows where 'Product' is 'Laptop'.
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500.
df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]

# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor'
# (using .loc and .iloc).
val3_4 = df_sales.loc[df_sales['Product'] == 'Monitor', 'Sales'].iloc[0]

# Display the results
print("\ndf3_1:")
print(df3_1.head())

print("\ndf3_2:")
print(df3_2.head())

print("\ndf3_3:")
print(df3_3.head())

print("\nFirst 'Sales' value where Product is 'Monitor':")
print(val3_4)# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")

# 3.1 Select only the 'Region' and 'Sales' columns.
df3_1 = df_sales[['Region', 'Sales']]

# 3.2 Select rows where 'Product' is 'Laptop'.
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500.
df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]

# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor'
# (using .loc and .iloc).
val3_4 = df_sales.loc[df_sales['Product'] == 'Monitor', 'Sales'].iloc[0]

# Display the results
print("\ndf3_1:")
print(df3_1.head())

print("\ndf3_2:")
print(df3_2.head())

print("\ndf3_3:")
print(df3_3.head())

print("\nFirst 'Sales' value where Product is 'Monitor':")
print(val3_4)# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")

# 3.1 Select only the 'Region' and 'Sales' columns.
df3_1 = df_sales[['Region', 'Sales']]

# 3.2 Select rows where 'Product' is 'Laptop'.
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500.
df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]

# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor'
# (using .loc and .iloc).
val3_4 = df_sales.loc[df_sales['Product'] == 'Monitor', 'Sales'].iloc[0]

# Display the results
print("\ndf3_1:")
print(df3_1.head())

print("\ndf3_2:")
print(df3_2.head())

print("\ndf3_3:")
print(df3_3.head())

print("\nFirst 'Sales' value where Product is 'Monitor':")
print(val3_4)# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")

# 3.1 Select only the 'Region' and 'Sales' columns.
df3_1 = df_sales[['Region', 'Sales']]

# 3.2 Select rows where 'Product' is 'Laptop'.
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500.
df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]

# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor'
# (using .loc and .iloc).
val3_4 = df_sales.loc[df_sales['Product'] == 'Monitor', 'Sales'].iloc[0]

# Display the results
print("\ndf3_1:")
print(df3_1.head())

print("\ndf3_2:")
print(df3_2.head())

print("\ndf3_3:")
print(df3_3.head())

print("\nFirst 'Sales' value where Product is 'Monitor':")
print(val3_4)# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")

# 3.1 Select only the 'Region' and 'Sales' columns.
df3_1 = df_sales[['Region', 'Sales']]

# 3.2 Select rows where 'Product' is 'Laptop'.
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500.
df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]

# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor'
# (using .loc and .iloc).
val3_4 = df_sales.loc[df_sales['Product'] == 'Monitor', 'Sales'].iloc[0]

# Display the results
print("\ndf3_1:")
print(df3_1.head())

print("\ndf3_2:")
print(df3_2.head())

print("\ndf3_3:")
print(df3_3.head())

print("\nFirst 'Sales' value where Product is 'Monitor':")
print(val3_4)


# Task 4: Data Cleaning (Handling Missing Values)
print("\n--- Task 4: Data Cleaning (Handling Missing Values) ---")
# Use 'df_sales' from Task 2 (which should have NaNs).
# 4.1 Check how many missing values are in each column. Store the result in 'missing_counts4_1'.
# 4.2 Fill missing 'Sales' values with the mean of the 'Sales' column. Store the modified DataFrame in 'df4_2_filled'.
# 4.3 Drop rows that have any missing values in 'df_sales'. Store the result in 'df4_3_dropped'.

# Your code for Task 4 here:
# Task 4: Data Cleaning (Handling Missing Values)
print("\n--- Task 4: Data Cleaning (Handling Missing Values) ---")

# 4.1 Check how many missing values are in each column.
missing_counts4_1 = df_sales.isnull().sum()

# 4.2 Fill missing 'Sales' values with the mean of the 'Sales' column.
df4_2_filled = df_sales.copy()
df4_2_filled['Sales'] = df4_2_filled['Sales'].fillna(df4_2_filled['Sales'].mean())

# 4.3 Drop rows that have any missing values in 'df_sales'.
df4_3_dropped = df_sales.dropna()

# Display the results
print("\nMissing values in each column:")
print(missing_counts4_1)

print("\nDataFrame after filling missing 'Sales' values:")
print(df4_2_filled.head())

print("\nDataFrame after dropping rows with missing values:")
print(df4_3_dropped.head())


# Task 5: Data Manipulation (Columns, Sorting, Grouping)
print("\n--- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---")
# Use 'df_sales' (the original one with NaNs)
# 5.1 Create a new column 'Total_Revenue' which is 'Sales' * 'Quantity'.
#     (Be mindful of NaNs, the result should also be NaN where either Sales or Quantity is NaN).
# 5.2 Sort 'df_sales' by 'Date' in ascending order, then by 'Sales' in descending order. Store it in 'df5_2_sorted'.
# 5.3 Group 'df_sales' by 'Region' and calculate the sum of 'Sales' and 'Quantity' for each region.
#     Store the result in 'df5_3_grouped_region'.
# 5.4 Group 'df_sales' by 'Product' and find the average 'Sales' for each product.
#     Store the result in 'df5_4_grouped_product'.

# Your code for Task 5 here:
# Task 5: Data Manipulation (Columns, Sorting, Grouping)
print("\n--- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---")

# 5.1 Create a new column 'Total_Revenue' = Sales * Quantity
df_sales['Total_Revenue'] = df_sales['Sales'] * df_sales['Quantity']

# 5.2 Sort by 'Date' (ascending) and then by 'Sales' (descending)
df5_2_sorted = df_sales.sort_values(by=['Date', 'Sales'],
                                    ascending=[True, False])

# 5.3 Group by 'Region' and calculate the sum of 'Sales' and 'Quantity'
df5_3_grouped_region = df_sales.groupby('Region')[['Sales', 'Quantity']].sum()

# 5.4 Group by 'Product' and calculate the average 'Sales'
df5_4_grouped_product = df_sales.groupby('Product')['Sales'].mean()

# Display the results
print("\nDataFrame with 'Total_Revenue':")
print(df_sales.head())

print("\nSorted DataFrame:")
print(df5_2_sorted.head())

print("\nTotal Sales and Quantity by Region:")
print(df5_3_grouped_region)

print("\nAverage Sales by Product:")
print(df5_4_grouped_product)
# Out:
# --- Intermediate Pandas Exercise ---
# Complete each task by writing the requested Pandas code.
# ------------------------------------
#
# --- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---
# --- Intermediate Pandas Exercise ---
# Complete each task by writing the requested Pandas code.
# ------------------------------------
#
# --- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---
#
# Series s1_1:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# NumPy Array np_array1_2:
# [[86 27 24 18]
#  [50 99 96 26]
#  [37 65 31 24]]
#
# DataFrame df1_3:
#     A   B   C   D
# 0  86  27  24  18
# 1  50  99  96  26
# 2  37  65  31  24
#
# --- Task 2: Synthetic Data Generation for Practice ---
#
# --- Task 2: Synthetic Data Generation for Practice ---
#         Date Region   Product  Sales  Quantity
# 0 2023-01-01   West    Laptop    NaN       2.0
# 1 2023-01-02   West   Monitor  346.0       8.0
# 2 2023-01-03   West  Keyboard  366.0       3.0
# 3 2023-01-04  North     Mouse  847.0      10.0
# 4 2023-01-05  North  Keyboard  892.0       5.0
#
# Missing values in each column:
# Date        0
# Region      0
# Product     0
# Sales       5
# Quantity    3
# dtype: int64
#
# --- Task 3: Indexing and Slicing in DataFrames ---
#
# --- Task 3: Indexing and Slicing in DataFrames ---
#
# df3_1:
#   Region  Sales
# 0   West    NaN
# 1   West  346.0
# 2   West  366.0
# 3  North  847.0
# 4  North  892.0
#
# df3_2:
#          Date Region Product  Sales  Quantity
# 0  2023-01-01   West  Laptop    NaN       2.0
# 8  2023-01-09  North  Laptop  427.0       9.0
# 10 2023-01-11   West  Laptop  324.0       NaN
# 16 2023-01-17   West  Laptop  572.0       5.0
# 20 2023-01-21  South  Laptop  945.0       7.0
#
# df3_3:
#          Date Region   Product  Sales  Quantity
# 18 2023-01-19   East     Mouse  854.0       6.0
# 26 2023-01-27   East     Mouse  548.0       3.0
# 27 2023-01-28   East  Keyboard  541.0       3.0
# 30 2023-01-31   East   Monitor  640.0       4.0
# 53 2023-02-23   East  Keyboard  546.0       4.0
#
# First 'Sales' value where Product is 'Monitor':
# 346.0
#
# --- Task 3: Indexing and Slicing in DataFrames ---
#
# df3_1:
#   Region  Sales
# 0   West    NaN
# 1   West  346.0
# 2   West  366.0
# 3  North  847.0
# 4  North  892.0
#
# df3_2:
#          Date Region Product  Sales  Quantity
# 0  2023-01-01   West  Laptop    NaN       2.0
# 8  2023-01-09  North  Laptop  427.0       9.0
# 10 2023-01-11   West  Laptop  324.0       NaN
# 16 2023-01-17   West  Laptop  572.0       5.0
# 20 2023-01-21  South  Laptop  945.0       7.0
#
# df3_3:
#          Date Region   Product  Sales  Quantity
# 18 2023-01-19   East     Mouse  854.0       6.0
# 26 2023-01-27   East     Mouse  548.0       3.0
# 27 2023-01-28   East  Keyboard  541.0       3.0
# 30 2023-01-31   East   Monitor  640.0       4.0
# 53 2023-02-23   East  Keyboard  546.0       4.0
#
# First 'Sales' value where Product is 'Monitor':
# 346.0
#
# --- Task 3: Indexing and Slicing in DataFrames ---
#
# df3_1:
#   Region  Sales
# 0   West    NaN
# 1   West  346.0
# 2   West  366.0
# 3  North  847.0
# 4  North  892.0
#
# df3_2:
#          Date Region Product  Sales  Quantity
# 0  2023-01-01   West  Laptop    NaN       2.0
# 8  2023-01-09  North  Laptop  427.0       9.0
# 10 2023-01-11   West  Laptop  324.0       NaN
# 16 2023-01-17   West  Laptop  572.0       5.0
# 20 2023-01-21  South  Laptop  945.0       7.0
#
# df3_3:
#          Date Region   Product  Sales  Quantity
# 18 2023-01-19   East     Mouse  854.0       6.0
# 26 2023-01-27   East     Mouse  548.0       3.0
# 27 2023-01-28   East  Keyboard  541.0       3.0
# 30 2023-01-31   East   Monitor  640.0       4.0
# 53 2023-02-23   East  Keyboard  546.0       4.0
#
# First 'Sales' value where Product is 'Monitor':
# 346.0
#
# --- Task 3: Indexing and Slicing in DataFrames ---
#
# df3_1:
#   Region  Sales
# 0   West    NaN
# 1   West  346.0
# 2   West  366.0
# 3  North  847.0
# 4  North  892.0
#
# df3_2:
#          Date Region Product  Sales  Quantity
# 0  2023-01-01   West  Laptop    NaN       2.0
# 8  2023-01-09  North  Laptop  427.0       9.0
# 10 2023-01-11   West  Laptop  324.0       NaN
# 16 2023-01-17   West  Laptop  572.0       5.0
# 20 2023-01-21  South  Laptop  945.0       7.0
#
# df3_3:
#          Date Region   Product  Sales  Quantity
# 18 2023-01-19   East     Mouse  854.0       6.0
# 26 2023-01-27   East     Mouse  548.0       3.0
# 27 2023-01-28   East  Keyboard  541.0       3.0
# 30 2023-01-31   East   Monitor  640.0       4.0
# 53 2023-02-23   East  Keyboard  546.0       4.0
#
# First 'Sales' value where Product is 'Monitor':
# 346.0
#
# --- Task 3: Indexing and Slicing in DataFrames ---
#
# df3_1:
#   Region  Sales
# 0   West    NaN
# 1   West  346.0
# 2   West  366.0
# 3  North  847.0
# 4  North  892.0
#
# df3_2:
#          Date Region Product  Sales  Quantity
# 0  2023-01-01   West  Laptop    NaN       2.0
# 8  2023-01-09  North  Laptop  427.0       9.0
# 10 2023-01-11   West  Laptop  324.0       NaN
# 16 2023-01-17   West  Laptop  572.0       5.0
# 20 2023-01-21  South  Laptop  945.0       7.0
#
# df3_3:
#          Date Region   Product  Sales  Quantity
# 18 2023-01-19   East     Mouse  854.0       6.0
# 26 2023-01-27   East     Mouse  548.0       3.0
# 27 2023-01-28   East  Keyboard  541.0       3.0
# 30 2023-01-31   East   Monitor  640.0       4.0
# 53 2023-02-23   East  Keyboard  546.0       4.0
#
# First 'Sales' value where Product is 'Monitor':
# 346.0
#
# --- Task 3: Indexing and Slicing in DataFrames ---
#
# df3_1:
#   Region  Sales
# 0   West    NaN
# 1   West  346.0
# 2   West  366.0
# 3  North  847.0
# 4  North  892.0
#
# df3_2:
#          Date Region Product  Sales  Quantity
# 0  2023-01-01   West  Laptop    NaN       2.0
# 8  2023-01-09  North  Laptop  427.0       9.0
# 10 2023-01-11   West  Laptop  324.0       NaN
# 16 2023-01-17   West  Laptop  572.0       5.0
# 20 2023-01-21  South  Laptop  945.0       7.0
#
# df3_3:
#          Date Region   Product  Sales  Quantity
# 18 2023-01-19   East     Mouse  854.0       6.0
# 26 2023-01-27   East     Mouse  548.0       3.0
# 27 2023-01-28   East  Keyboard  541.0       3.0
# 30 2023-01-31   East   Monitor  640.0       4.0
# 53 2023-02-23   East  Keyboard  546.0       4.0
#
# First 'Sales' value where Product is 'Monitor':
# 346.0
#
# --- Task 3: Indexing and Slicing in DataFrames ---
#
# df3_1:
#   Region  Sales
# 0   West    NaN
# 1   West  346.0
# 2   West  366.0
# 3  North  847.0
# 4  North  892.0
#
# df3_2:
#          Date Region Product  Sales  Quantity
# 0  2023-01-01   West  Laptop    NaN       2.0
# 8  2023-01-09  North  Laptop  427.0       9.0
# 10 2023-01-11   West  Laptop  324.0       NaN
# 16 2023-01-17   West  Laptop  572.0       5.0
# 20 2023-01-21  South  Laptop  945.0       7.0
#
# df3_3:
#          Date Region   Product  Sales  Quantity
# 18 2023-01-19   East     Mouse  854.0       6.0
# 26 2023-01-27   East     Mouse  548.0       3.0
# 27 2023-01-28   East  Keyboard  541.0       3.0
# 30 2023-01-31   East   Monitor  640.0       4.0
# 53 2023-02-23   East  Keyboard  546.0       4.0
#
# First 'Sales' value where Product is 'Monitor':
# 346.0
#
# --- Task 4: Data Cleaning (Handling Missing Values) ---
#
# --- Task 4: Data Cleaning (Handling Missing Values) ---
#
# Missing values in each column:
# Date        0
# Region      0
# Product     0
# Sales       5
# Quantity    3
# dtype: int64
#
# DataFrame after filling missing 'Sales' values:
#         Date Region   Product       Sales  Quantity
# 0 2023-01-01   West    Laptop  557.936842       2.0
# 1 2023-01-02   West   Monitor  346.000000       8.0
# 2 2023-01-03   West  Keyboard  366.000000       3.0
# 3 2023-01-04  North     Mouse  847.000000      10.0
# 4 2023-01-05  North  Keyboard  892.000000       5.0
#
# DataFrame after dropping rows with missing values:
#         Date Region   Product  Sales  Quantity
# 1 2023-01-02   West   Monitor  346.0       8.0
# 2 2023-01-03   West  Keyboard  366.0       3.0
# 3 2023-01-04  North     Mouse  847.0      10.0
# 4 2023-01-05  North  Keyboard  892.0       5.0
# 5 2023-01-06  South     Mouse  744.0       6.0
#
# --- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---
#
# --- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---
#
# DataFrame with 'Total_Revenue':
#         Date Region   Product  Sales  Quantity  Total_Revenue
# 0 2023-01-01   West    Laptop    NaN       2.0            NaN
# 1 2023-01-02   West   Monitor  346.0       8.0         2768.0
# 2 2023-01-03   West  Keyboard  366.0       3.0         1098.0
# 3 2023-01-04  North     Mouse  847.0      10.0         8470.0
# 4 2023-01-05  North  Keyboard  892.0       5.0         4460.0
#
# Sorted DataFrame:
#         Date Region   Product  Sales  Quantity  Total_Revenue
# 0 2023-01-01   West    Laptop    NaN       2.0            NaN
# 1 2023-01-02   West   Monitor  346.0       8.0         2768.0
# 2 2023-01-03   West  Keyboard  366.0       3.0         1098.0
# 3 2023-01-04  North     Mouse  847.0      10.0         8470.0
# 4 2023-01-05  North  Keyboard  892.0       5.0         4460.0
#
# Total Sales and Quantity by Region:
#           Sales  Quantity
# Region
# East    12589.0     132.0
# North   12117.0     125.0
# South   13480.0     134.0
# West    14818.0     128.0
#
# Average Sales by Product:
# Product
# Keyboard    595.375000
# Laptop      589.631579
# Monitor     506.700000
# Mouse       543.062500
# Name: Sales, dtype: float64
